# %% [markdown]
# <a href="https://colab.research.google.com/github/albertr808/edd_1310_2021/blob/master/15ctubre2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #modulos
# Son recursos utilizables que contienen varias funciones que pueden ser importadas a tu codigo

# %%
 import modulo

x =modulo.sumar(4,7) 
print(x)
x =modulo.multiplicar(4,7)
print(x)
# Out:
# 11
# 28

# %%
from modulo import sumar,dividir
print(sumar(4,7))
print(dividir(14,7))
# Out:
# 11
# 2.0

# %%
import modulo as patito
print(patito.sumar(4,6))
# Out:
# 10

# %%
pip install joke-generator

# %%
from joke_generator import generate

generate()
# Out:
# 'I wear a stethoscope so that in a medical emergency I can teach people a valuable lesson about assumptions.'

# %% [markdown]
# #archivos
# -open(str,str)
#
#   1-nombre o ruta del archivo
#
#
#    2-dos caracteres
#
#   -modo de apertura del archivo (r,w,a,x append si y solo si el archivo no existe)
#
#   -formato del archivo (tob)

# %%
archivo=open("saludo.txt","wt")
archivo.write("hola mundo\ Ola k hace")
archivo.close
# Out:
# <function TextIOWrapper.close>

# %%
#otro=open("./sample_data/anscombe.json","rt")
#datos=otro.read()
#print(datos)
#otro.close

arch=open("frutas.txt","rt")
data="ppp"
while (data!=""):
  data=arch.readline()
  print(data)
arch.close()

arch=open("frutas.txt","rt")
list_frutas=arch.readline()
print(list_frutas)
arch.close()
# Out:
# manzana,pera,kiwi,,aguacate,
#
# manzana,limon,naranja
#
# ,sandia,papaya
#
# manzana,pera,kiwi,,aguacate,

# %%
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-57993071d929> in <module>()
#       3 while (data!=" "):
#       4   data=arch.readline()
# ----> 5   print(data)
#       6 arch.close()
#       7
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
# ...
